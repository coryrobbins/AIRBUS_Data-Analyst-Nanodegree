# %% [markdown]
# ## JSON Playground

# %%
def main():
    results = query_by_name(ARTIST_URL, query_type["simple"], "Lucero")
    
    arist_id = results["artists"][1]["id"]
    print("\nARTIST::")
    pretty_print(resluts["artist"][1])


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0d72983baab8> in <module>
#       8
#       9 if __name__ == '__main__':
# ---> 10     main()
#      11
#
# <ipython-input-5-0d72983baab8> in main()
#       1 def main():
# ----> 2     results = query_by_name(ARTIST_URL, query_type["simple"], "Lucero")
#       3
#       4     arist_id = results["artists"][1]["id"]
#       5     print("\nARTIST::")
#
# NameError: name 'query_by_name' is not defined

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)

# %%
"""
To experiment with this code freely you will have to run this code locally.
Take a look at the main() function for an example of how to use the code. We
have provided example json output in the other code editor tabs for you to look
at, but you will not be able to run any queries through our UI.
"""
import json
import requests

BASE_URL = "http://musicbrainz.org/ws/2/"
ARTIST_URL = BASE_URL + "artist/"


# query parameters are given to the requests.get function as a dictionary; this
# variable contains some starter parameters.
query_type = {  "simple": {},
                "atr": {"inc": "aliases+tags+ratings"},
                "aliases": {"inc": "aliases"},
                "releases": {"inc": "releases"}}


def query_site(url, params, uid="", fmt="json"):
    """
    This is the main function for making queries to the musicbrainz API. The
    query should return a json document.
    """
    params["fmt"] = fmt
    r = requests.get(url + uid, params=params)
    print("requesting", r.url)

    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()


def query_by_name(url, params, name):
    """
    This adds an artist name to the query parameters before making an API call
    to the function above.
    """
    params["query"] = "artist:" + name
    return query_site(url, params)


def pretty_print(data, indent=4):
    """
    After we get our output, we can use this function to format it to be more
    readable.
    """
    if type(data) == dict:
        print(json.dumps(data, indent=indent, sort_keys=True))
    else:
        print(data)


def main():
    """
    Below is an example investigation to help you get started in your
    exploration. Modify the function calls and indexing below to answer the
    questions on the next quiz.

    HINT: Note how the output we get from the site is a multi-level JSON
    document, so try making print statements to step through the structure one
    level at a time or copy the output to a separate output file. Experimenting
    and iteration will be key to understand the structure of the data!
    """

    # Query for information in the database about bands named Nirvana
    results = query_by_name(ARTIST_URL, query_type["simple"], "Nirvana")
    pretty_print(results)

    # Isolate information from the 4th band returned (index 3)
    print("\nARTIST:")
    pretty_print(results["artists"][3])

    # Query for releases from that band using the artist_id
    artist_id = results["artists"][3]["id"]
    artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)
    releases = artist_data["releases"]

    # Print information about releases from the selected band
    print("\nONE RELEASE:")
    pretty_print(releases[0], indent=2)

    release_titles = [r["title"] for r in releases]
    print("\nALL TITLES:")
    for t in release_titles:
        print(t)

if __name__ == '__main__':
    main()
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3ANirvana&fmt=json
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana US",
#                     "primary": null,
#                     "sort-name": "Nirvana US",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ja",
#                     "name": "\u30cb\u30eb\u30f4\u30a1\u30fc\u30ca",
#                     "primary": true,
#                     "sort-name": "\u30cb\u30eb\u30f4\u30a1\u30fc\u30ca",
#                     "type": "Artist name",
#                     "type-id": "894afba6-2816-3c24-8072-eadb66bd04bc"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "en",
#                     "name": "Nirvana",
#                     "primary": true,
#                     "sort-name": "Nirvana",
#                     "type": "Artist name",
#                     "type-id": "894afba6-2816-3c24-8072-eadb66bd04bc"
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "United States",
#                 "sort-name": "United States",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "begin-area": {
#                 "id": "a640b45c-c173-49b1-8030-973603e895b5",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Aberdeen",
#                 "sort-name": "Aberdeen",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "country": "US",
#             "disambiguation": "90s US grunge band",
#             "id": "5b11f4ce-a62d-471e-81fc-a69a8278c7da",
#             "isnis": [
#                 "0000000123486830",
#                 "0000000123487390"
#             ],
#             "life-span": {
#                 "begin": "1988-01",
#                 "end": "1994-04-05",
#                 "ended": true
#             },
#             "name": "Nirvana",
#             "score": 100,
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 3,
#                     "name": "seattle"
#                 },
#                 {
#                     "count": 2,
#                     "name": "90s"
#                 },
#                 {
#                     "count": 0,
#                     "name": "alternative"
#                 },
#                 {
#                     "count": 2,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 2,
#                     "name": "experimental"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united states"
#                 },
#                 {
#                     "count": 0,
#                     "name": "am\u00e9ricain"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kurt cobain"
#                 },
#                 {
#                     "count": 2,
#                     "name": "usa"
#                 },
#                 {
#                     "count": 0,
#                     "name": "90"
#                 },
#                 {
#                     "count": 11,
#                     "name": "alternative rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock and indie"
#                 },
#                 {
#                     "count": 0,
#                     "name": "legendary"
#                 },
#                 {
#                     "count": 0,
#                     "name": "northwest"
#                 },
#                 {
#                     "count": 27,
#                     "name": "grunge"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 8,
#                     "name": "american"
#                 },
#                 {
#                     "count": 17,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "noise rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "nirvana"
#                 },
#                 {
#                     "count": 1,
#                     "name": "acoustic rock"
#                 }
#             ],
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "London",
#                 "sort-name": "London",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "country": "GB",
#             "disambiguation": "60s band from the UK",
#             "id": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#             "life-span": {
#                 "begin": "1967",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": 79,
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 0,
#                     "name": "orchestral"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "psychedelic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "symphonic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "baroque pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "psychedelic pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "english"
#                 },
#                 {
#                     "count": 1,
#                     "name": "soft rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "rock"
#                 }
#             ],
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "United States",
#                 "sort-name": "United States",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "US",
#             "id": "c3a64a25-251b-4d03-afba-1471440245b8",
#             "life-span": {
#                 "begin": "2009",
#                 "ended": null
#             },
#             "name": "Approaching Nirvana",
#             "score": 74,
#             "sort-name": "Approaching Nirvana",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "France",
#                 "sort-name": "France",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "FR",
#             "disambiguation": "\u201970s French band from Martigues",
#             "id": "c49d69dc-e008-47cf-b5ff-160fafb1fe1f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": 71,
#             "sort-name": "Nirvana",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "6a264f94-6ff1-30b1-9a81-41f7bfabd616",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Finland",
#                 "sort-name": "Finland",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "FI",
#             "disambiguation": "Early 1980's Finnish punk band",
#             "id": "85af0709-95db-4fbc-801a-120e9f4766d0",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": 70,
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "finland"
#                 }
#             ],
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "885dce63-c211-3033-8cf7-46cb82d440c7",
#                 "life-span": {
#                     "begin": "1918",
#                     "end": "2003",
#                     "ended": true
#                 },
#                 "name": "Yugoslavia",
#                 "sort-name": "Yugoslavia",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "YU",
#             "disambiguation": "Croatian prog-rock band active in first half of 70s in former Yugoslavia.",
#             "id": "28a4618c-38e4-4027-ad2c-db66a14a2d85",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": 70,
#             "sort-name": "Nirvana",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "disambiguation": "founded in 1987 by a Michael Jackson double/imitator",
#             "id": "3aa878c0-224b-41e5-abd1-63be359d2bca",
#             "life-span": {
#                 "begin": "1987",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": 70,
#             "sort-name": "Nirvana"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": "1988",
#                     "end-date": "1988",
#                     "locale": null,
#                     "name": "Prophet 2002",
#                     "primary": null,
#                     "sort-name": "Prophet 2002",
#                     "type": null
#                 },
#                 {
#                     "begin-date": "1988",
#                     "end-date": "1988",
#                     "locale": null,
#                     "name": "Nirvana",
#                     "primary": null,
#                     "sort-name": "Nirvana",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "N2K2",
#                     "primary": null,
#                     "sort-name": "N2K2",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Sweden",
#                 "sort-name": "Sweden",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish death metal band",
#             "id": "f2dfdff9-3862-4be0-bf85-9c833fa3059e",
#             "life-span": {
#                 "begin": "1988",
#                 "end": "2012",
#                 "ended": true
#             },
#             "name": "Nirvana 2002",
#             "score": 63,
#             "sort-name": "Nirvana 2002",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "id": "329c04ae-3b73-4ca3-996f-75608ab1befb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Singh",
#             "score": 62,
#             "sort-name": "Singh, Nirvana",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "89e9ed9d-9b45-42ad-bce2-54ef36053a1a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Seekerz",
#             "score": 62,
#             "sort-name": "Nirvana Seekerz",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "id": "86f9ae24-ba2a-4d55-9275-0b89b85f6e3a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Weed Nirvana",
#             "score": 62,
#             "sort-name": "Weed Nirvana"
#         },
#         {
#             "id": "b305320e-c158-43f4-b5be-4450e2f99a32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "El Nirvana",
#             "score": 62,
#             "sort-name": "Nirvana, El"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "United States",
#                 "sort-name": "United States",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "US",
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "206419e0-3a7a-49ce-8437-4e757767d02b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Savoury",
#             "score": 62,
#             "sort-name": "Savoury, Nirvana",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "d3a68bd0-7419-3f99-a5bd-204d6e057089",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Indonesia",
#                 "sort-name": "Indonesia",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "ID",
#             "disambiguation": "experimental",
#             "id": "7c525bf4-abf0-42e3-a1bd-81cbcb55c1f4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Genta Nirvana",
#             "score": 62,
#             "sort-name": "Genta Nirvana"
#         },
#         {
#             "id": "74ba0d66-e029-4b2e-9bd2-627b0febdc1d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Cheick Nirvana",
#             "score": 62,
#             "sort-name": "Cheick Nirvana"
#         },
#         {
#             "id": "f58febd3-18de-4371-8d95-4a68d4f79456",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Kelly",
#             "score": 61,
#             "sort-name": "Kelly, Nirvana",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "07607044-8140-47ba-bb24-7129babe586b",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "West Midlands",
#                 "sort-name": "West Midlands",
#                 "type": "Subdivision",
#                 "type-id": "fd3d44c5-80a1-3842-9745-2c4972d35afa"
#             },
#             "id": "8f32371e-4bac-4090-ba13-2c1cd1aeab0d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana UK",
#             "score": 61,
#             "sort-name": "Nirvana UK",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "begin-area": {
#                 "id": "ef1b7cc0-cd26-36f4-8ea0-04d9623786c7",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Netherlands",
#                 "sort-name": "Netherlands",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "id": "da77e424-c473-481e-a2ae-5d966b2ee0b6",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Undercover",
#             "score": 61,
#             "sort-name": "Nirvana Undercover",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Houston",
#                 "sort-name": "Houston",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "begin-area": {
#                 "id": "c920948b-83e3-40b7-8fe9-9ab5abaac55b",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Houston",
#                 "sort-name": "Houston",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "disambiguation": "Nirvana Cover Band",
#             "id": "45eacd92-6857-4faa-9283-023e72a1d4b1",
#             "life-span": {
#                 "begin": "2012",
#                 "ended": null
#             },
#             "name": "The Nirvana Experience",
#             "score": 56,
#             "sort-name": "The Nirvana Experience",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "id": "e43ad11b-5d29-45ae-90f7-73ac47fb815d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "smells like nirvana",
#             "score": 56,
#             "sort-name": "smells like nirvana"
#         },
#         {
#             "area": {
#                 "id": "5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Belgium",
#                 "sort-name": "Belgium",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "BE",
#             "disambiguation": "Belgian",
#             "id": "1d512080-0ef7-454f-a325-9bf5ff95ce88",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Come As Nirvana",
#             "score": 56,
#             "sort-name": "Come As Nirvana",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "begin-area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "id": "02c4e6bb-7b7a-4686-8c23-df01bfd42b0e",
#             "life-span": {
#                 "begin": "2012-04-05",
#                 "ended": null
#             },
#             "name": "Sappy Nirvana Tribute",
#             "score": 56,
#             "sort-name": "Sappy Nirvana Tribute",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Graz",
#                 "sort-name": "Graz",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "begin-area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Graz",
#                 "sort-name": "Graz",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "disambiguation": "Nirvana-Coverband",
#             "id": "46d8dae4-abec-438b-9c62-a3dbb2aaa1b7",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "Nirvana Teen Spirit",
#             "score": 56,
#             "sort-name": "Nirvana Teen Spirit",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "id": "bb94730d-22c2-422d-a0a7-fe16a5b3e429",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Attainment of Nirvana",
#             "score": 52,
#             "sort-name": "Attainment of Nirvana, The",
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "id": "e1388435-f80d-434a-9980-f1c9f5aa9b90",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Sitar & String Group",
#             "score": 48,
#             "sort-name": "Nirvana Sitar & String Group"
#         }
#     ],
#     "count": 25,
#     "created": "2021-01-06T10:25:32.124Z",
#     "offset": 0
# }
#
# ARTIST:
# {
#     "area": {
#         "id": "08310658-51eb-3801-80de-5a0739207115",
#         "life-span": {
#             "ended": null
#         },
#         "name": "France",
#         "sort-name": "France",
#         "type": "Country",
#         "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#     },
#     "country": "FR",
#     "disambiguation": "\u201970s French band from Martigues",
#     "id": "c49d69dc-e008-47cf-b5ff-160fafb1fe1f",
#     "life-span": {
#         "ended": null
#     },
#     "name": "Nirvana",
#     "score": 71,
#     "sort-name": "Nirvana",
#     "type": "Group",
#     "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
# }
# requesting http://musicbrainz.org/ws/2/artist/c49d69dc-e008-47cf-b5ff-160fafb1fe1f?inc=releases&fmt=json
#
# ONE RELEASE:
# {
#   "barcode": null,
#   "country": null,
#   "date": "2016",
#   "disambiguation": "",
#   "id": "b0061b53-0095-4327-88d3-c88b317acfda",
#   "packaging": null,
#   "packaging-id": null,
#   "quality": "normal",
#   "release-events": [
#     {
#       "area": null,
#       "date": "2016"
#     }
#   ],
#   "status": "Official",
#   "status-id": "4e304316-386d-3409-af2e-78857eec5cfe",
#   "text-representation": {
#     "language": null,
#     "script": null
#   },
#   "title": "Remembering Le Futur"
# }
#
# ALL TITLES:
# Remembering Le Futur

# %%
# To experiment with this code freely you will have to run this code locally.
# We have provided an example json output here for you to look at,
# but you will not be able to run any queries through our UI.
import json
import requests


BASE_URL = "http://musicbrainz.org/ws/2/"
ARTIST_URL = BASE_URL + "artist/"

query_type = {  "simple": {},
                "atr": {"inc": "aliases+tags+ratings"},
                "aliases": {"inc": "aliases"},
                "releases": {"inc": "releases"}}


def query_site(url, params, uid="", fmt="json"):
    params["fmt"] = fmt
    r = requests.get(url + uid, params=params)
    print("requesting", r.url)

    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()


def query_by_name(url, params, name):
    params["query"] = "artist:" + name
    return query_site(url, params)


def pretty_print(data, indent=4):
    if type(data) == dict:
        print(json.dumps(data, indent=indent, sort_keys=True))
    else:
        print(data)


def main():
    results = query_by_name(ARTIST_URL, query_type["simple"], "Lucero")
    pretty_print(results)

    artist_id = results["artists"][1]["id"]
    print("\nARTIST:")
    pretty_print(results["artists"][1])

    artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)
    releases = artist_data["releases"]
    print("\nONE RELEASE:")
    pretty_print(releases[0], indent=2)
    release_titles = [r["title"] for r in releases]

    print("\nALL TITLES:")
    for t in release_titles:
        print(t)


if __name__ == '__main__':
    main()
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3ALucero&fmt=json
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "c2d96f61-75a4-4375-aed5-6aacb0b6326a",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Memphis",
#                 "sort-name": "Memphis",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "begin-area": {
#                 "id": "c2d96f61-75a4-4375-aed5-6aacb0b6326a",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Memphis",
#                 "sort-name": "Memphis",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "disambiguation": "Memphis, TN based band",
#             "id": "1a681dad-cb15-43be-9d0f-4a807badff9f",
#             "life-span": {
#                 "begin": "1998",
#                 "ended": null
#             },
#             "name": "Lucero",
#             "score": 100,
#             "sort-name": "Lucero",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "memphis soul"
#                 },
#                 {
#                     "count": 1,
#                     "name": "alternative country"
#                 },
#                 {
#                     "count": 1,
#                     "name": "southern rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "punk rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "alternative rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "blues rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "rockabilly"
#                 },
#                 {
#                     "count": 1,
#                     "name": "heartland rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "cowpunk"
#                 }
#             ],
#             "type": "Group",
#             "type-id": "e431f5f6-b5d2-343d-8b36-72607fffb74b"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Lucerito",
#                     "primary": null,
#                     "sort-name": "Lucerito",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "3e08b2cd-69f3-317c-b1e4-e71be581839e",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Mexico",
#                 "sort-name": "Mexico",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "begin-area": {
#                 "id": "3c810219-baf2-4fff-b98c-46b425eea1f5",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Ciudad de M\u00e9xico",
#                 "sort-name": "Ciudad de M\u00e9xico",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "country": "MX",
#             "disambiguation": "Mexican singer and actress",
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "4befe93e-7cb6-4adb-b822-8b19ceb59768",
#             "life-span": {
#                 "begin": "1969-08-29",
#                 "ended": null
#             },
#             "name": "Lucero",
#             "score": 99,
#             "sort-name": "Lucero",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "national folk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "latin"
#                 },
#                 {
#                     "count": 1,
#                     "name": "ranchera"
#                 }
#             ],
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "2826f824-7505-479c-834d-43e9861af11e",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Reyna Lucero",
#             "score": 78,
#             "sort-name": "Lucero, Reyna"
#         },
#         {
#             "area": {
#                 "id": "0df04709-c7d8-3b55-a6ea-f3e5069a947b",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Argentina",
#                 "sort-name": "Argentina",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "AR",
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "72e87d3a-7ada-4824-bf72-aabdd56c377d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Hern\u00e1n Lucero",
#             "score": 77,
#             "sort-name": "Lucero, Hern\u00e1n",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "471c46a7-afc5-31c4-923c-d0444f5053a4",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Spain",
#                 "sort-name": "Spain",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "begin-area": {
#                 "id": "b295cee3-2082-4c6c-8dbe-357626e292ce",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Durango",
#                 "sort-name": "Durango",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "country": "ES",
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "9193a87a-a5ec-4fa5-800e-63f139aca089",
#             "isnis": [
#                 "000000007277919X"
#             ],
#             "life-span": {
#                 "begin": "1938",
#                 "ended": null
#             },
#             "name": "Lucero Tena",
#             "score": 77,
#             "sort-name": "Tena, Lucero",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "aa5faf27-e0a5-42a6-9d0f-bb81cd6655fa",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Enrique Lucero",
#             "score": 76,
#             "sort-name": "Lucero, Enrique",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "tango"
#                 }
#             ],
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "36e09a0a-ef07-4446-9e20-e998d5e810cc",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Angelina Lucero",
#             "score": 76,
#             "sort-name": "Angelina Lucero"
#         },
#         {
#             "disambiguation": "tango singer",
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "80e730d8-0a16-494f-8113-47e26b73a5c7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Claudia Lucero",
#             "score": 76,
#             "sort-name": "Lucero, Claudia",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "tango"
#                 }
#             ],
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "d273b44b-1b0e-4810-b02b-717673deeb11",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Mark Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Mark",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "403368f9-94fa-4ccf-a3b3-23c1391b5c39",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Eric Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Eric",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "49b562a4-e546-4d0e-a2cd-8dd746f7f5bf",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Lucero Aguilar",
#             "score": 75,
#             "sort-name": "Aguilar, Lucero",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "5e29f7dc-f02e-49cf-b0bd-96065e9283ac",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "F. Lucero",
#             "score": 75,
#             "sort-name": "Lucero, F.",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "0cbdf987-cea8-424a-8296-98a50ff0d49c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nick Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Nick",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "United States",
#                 "sort-name": "United States",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "country": "US",
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "52551d74-064c-45b5-836f-d4b70032e6f6",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Anthony Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Anthony",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "3f179da4-83c6-4a28-a627-e46b4a8ff1ed",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Sydney",
#                 "sort-name": "Sydney",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "disambiguation": "Guitarist, Producer & Recording/Mixing Engineer \u2013 Sydney, NSW, Australia",
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "0a79578c-7a45-4614-aca2-5b4cec595b92",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Eduardo Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Eduardo",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "44c178e3-d716-4a48-a019-e29dae6c4ffc",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Chuck Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Chuck",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "fa015208-c59f-4f66-9719-e3bf06e3f561",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Jezrael Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Jezrael",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "0d46d254-4d3f-489f-b05b-3c7c06619701",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Drew Lucero",
#             "score": 75,
#             "sort-name": "Drew Lucero",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "begin-area": {
#                 "id": "0df04709-c7d8-3b55-a6ea-f3e5069a947b",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Argentina",
#                 "sort-name": "Argentina",
#                 "type": "Country",
#                 "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#             },
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "6d4d15dd-492f-4254-a0c3-a4332d8692ce",
#             "life-span": {
#                 "begin": "1920-03-03",
#                 "ended": null
#             },
#             "name": "Carlos Lucero",
#             "score": 75,
#             "sort-name": "Lucero, Carlos",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "tango"
#                 }
#             ],
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "area": {
#                 "id": "075e1cc9-9567-4317-a931-4f6dcecc688f",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Albuquerque",
#                 "sort-name": "Albuquerque",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "begin-area": {
#                 "id": "075e1cc9-9567-4317-a931-4f6dcecc688f",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Albuquerque",
#                 "sort-name": "Albuquerque",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "94fa67e0-d608-4f92-a6b4-9965f43135a1",
#             "ipis": [
#                 "00771016461"
#             ],
#             "life-span": {
#                 "begin": "1988-06-08",
#                 "ended": null
#             },
#             "name": "Mario J. Lucero",
#             "score": 71,
#             "sort-name": "Lucero, Mario J.",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "begin-area": {
#                 "id": "075e1cc9-9567-4317-a931-4f6dcecc688f",
#                 "life-span": {
#                     "ended": null
#                 },
#                 "name": "Albuquerque",
#                 "sort-name": "Albuquerque",
#                 "type": "City",
#                 "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#             },
#             "gender": "female",
#             "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#             "id": "2b9e822d-e379-4bdf-8183-54ce2ab2931b",
#             "life-span": {
#                 "begin": "1989-03-30",
#                 "ended": null
#             },
#             "name": "Isabel Ruiz Lucero",
#             "score": 71,
#             "sort-name": "Lucero, Isabel Ruiz",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "f25f9c9f-591f-404d-a5e1-d607ce626305",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Walter Molina Lucero",
#             "score": 68,
#             "sort-name": "Lucero, Walter Molina",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "2653dafd-c560-463e-b604-db24b1ac9f35",
#             "life-span": {
#                 "begin": "1910-10-26",
#                 "end": "1974-06-02",
#                 "ended": true
#             },
#             "name": "Alfredo Lucero Palacios",
#             "score": 68,
#             "sort-name": "Palacios, Alfredo Lucero",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "tango"
#                 }
#             ],
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         },
#         {
#             "id": "c24e0411-e33c-43b8-ba1e-4ef0f034aaac",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Lucero En Vivo",
#             "score": 68,
#             "sort-name": "Lucero En Vivo"
#         },
#         {
#             "gender": "male",
#             "gender-id": "36d3d30a-839d-3eda-8cb3-29be4384e4a9",
#             "id": "24b5ae5e-9063-402b-8ab9-ca7c7852711c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Juan Lucero Campas",
#             "score": 68,
#             "sort-name": "Lucero Campas, Juan",
#             "type": "Person",
#             "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
#         }
#     ],
#     "count": 25,
#     "created": "2021-01-07T03:54:20.879Z",
#     "offset": 0
# }
#
# ARTIST:
# {
#     "aliases": [
#         {
#             "begin-date": null,
#             "end-date": null,
#             "locale": null,
#             "name": "Lucerito",
#             "primary": null,
#             "sort-name": "Lucerito",
#             "type": null
#         }
#     ],
#     "area": {
#         "id": "3e08b2cd-69f3-317c-b1e4-e71be581839e",
#         "life-span": {
#             "ended": null
#         },
#         "name": "Mexico",
#         "sort-name": "Mexico",
#         "type": "Country",
#         "type-id": "06dd0ae4-8c74-30bb-b43d-95dcedf961de"
#     },
#     "begin-area": {
#         "id": "3c810219-baf2-4fff-b98c-46b425eea1f5",
#         "life-span": {
#             "ended": null
#         },
#         "name": "Ciudad de M\u00e9xico",
#         "sort-name": "Ciudad de M\u00e9xico",
#         "type": "City",
#         "type-id": "6fd8f29a-3d0a-32fc-980d-ea697b69da78"
#     },
#     "country": "MX",
#     "disambiguation": "Mexican singer and actress",
#     "gender": "female",
#     "gender-id": "93452b5a-a947-30c8-934f-6a4056b151c2",
#     "id": "4befe93e-7cb6-4adb-b822-8b19ceb59768",
#     "life-span": {
#         "begin": "1969-08-29",
#         "ended": null
#     },
#     "name": "Lucero",
#     "score": 99,
#     "sort-name": "Lucero",
#     "tags": [
#         {
#             "count": 1,
#             "name": "national folk"
#         },
#         {
#             "count": 1,
#             "name": "pop"
#         },
#         {
#             "count": 1,
#             "name": "latin"
#         },
#         {
#             "count": 1,
#             "name": "ranchera"
#         }
#     ],
#     "type": "Person",
#     "type-id": "b6e035f4-3ce9-331c-97df-83397230b0df"
# }
# requesting http://musicbrainz.org/ws/2/artist/4befe93e-7cb6-4adb-b822-8b19ceb59768?inc=releases&fmt=json
#
# ONE RELEASE:
# {
#   "barcode": "0053308001422",
#   "country": "US",
#   "date": "1991-07-01",
#   "disambiguation": "",
#   "id": "1f801e2e-6367-426b-9e99-45aca01ad45a",
#   "packaging": null,
#   "packaging-id": null,
#   "quality": "normal",
#   "release-events": [
#     {
#       "area": {
#         "disambiguation": "",
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "iso-3166-1-codes": [
#           "US"
#         ],
#         "name": "United States",
#         "sort-name": "United States",
#         "type": null,
#         "type-id": null
#       },
#       "date": "1991-07-01"
#     }
#   ],
#   "status": "Official",
#   "status-id": "4e304316-386d-3409-af2e-78857eec5cfe",
#   "text-representation": {
#     "language": "spa",
#     "script": "Latn"
#   },
#   "title": "Lucerito"
# }
#
# ALL TITLES:
# Lucerito
# Sólo pienso en ti
# Lucero de México
# 18 éxitos
# Cariño de mis cariños!
# Siempre contigo
# Lucero
# Piel de ángel
# Cerca de ti
# Cuéntame
# Mi destino
# Un Lucero en la México
# Un Lucero en la México 2
# 15 éxitos
# Un nuevo amor
# Cuando sale un Lucero
# 20 éxitos originales
# Quiéreme tal como soy
# Con mi sentimiento
# Lazos de amor
# Dueña de tu amor
# Indispensable
# Esta vez la primera soy yo
# Costumbres
# Un Lu*Jo

# %% [markdown]
# ## https://notebook.community/loujine/musicbrainz-dataviz/0-introduction
# > Visualizing MusicBrainz data with Python/JS, an introduction
#
# > https://github.com/loujine/musicbrainz-docker
#
# > https://github.com/loujine/musicbrainz-docker/tree/master/indexer-dockerfile

# %%
# !pip install watermark
# Out:
# Collecting watermark
#   Downloading watermark-2.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: ipython in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from watermark) (7.19.0)
# Requirement already satisfied: decorator in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (50.3.1.post20201107)
# Requirement already satisfied: backcall in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.17.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (3.0.8)
# Requirement already satisfied: pickleshare in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: pygments in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (2.7.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (5.0.5)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from ipython->watermark) (0.1.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->watermark) (0.6.0)
# Requirement already satisfied: ipython-genutils in /Users/coryrobbins/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->watermark) (0.2.0)
# Installing collected packages: watermark
# Successfully installed watermark-2.1.0

# %%
# %load_ext watermark
# %watermark --python -r
# Out:
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.19.0
#
# Git repo:

# %%
# %watermark --date --updated
# Out:
# Last updated: 2021-01-07

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.8.6-cp38-cp38-macosx_10_9_x86_64.macosx_10_9_intel.macosx_10_10_intel.macosx_10_10_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 554 kB/s eta 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.8.6

# %%
import os
import psycopg2

#define global variables to store our DB credentials

PGHOST = 'localhost'
PGDATABASE = os.environ.get('PGUSER', 'musicbrainz')
PGUSER = os.environ.get('PGUSER', 'musicbrainz')
PGPASSWORD = os.environ.get('PGPASSWORD', 'musicbrainz')

# %%
sql_beethoven = """
SELECT gid, name, begin_date_year, end_date_year 
  FROM artist 
 WHERE name='Ludwig van Beethoven'
"""

# %%
with psycopg2.connect(host=PGHOST, database=PGDATABASE, 
                      user=PGUSER, password=PGPASSWORD) as cnx:
    crs = cnx.cursor()
    crs.execute(sql_beethoven)
    for result in crs:
        print(result)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-76519e385881> in <module>
# ----> 1 with psycopg2.connect(host=PGHOST, database=PGDATABASE,
#       2                       user=PGUSER, password=PGPASSWORD) as cnx:
#       3     crs = cnx.cursor()
#       4     crs.execute(sql_beethoven)
#       5     for result in crs:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
